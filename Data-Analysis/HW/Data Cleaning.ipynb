# %%
# %pwd
# Out:
# 'C:\\MyNotebook'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
iris = pd.read_csv("HW.csv", sep=',')
iris.head()
# Out:
#    DISTR1:3939ICT  MUNICIPALITY  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  \
# 0              11          2301            2            6         1255
# 1              11          2301            2            7         1752
# 2              11          2121            4            2         2321
# 3              11          2301            5            6         2340
# 4              11          2301            5            1         1450
#
#    HOUR_OF_DAY  ILLUMINATION  WEATHER  ROAD_CONDITION  COLLISION_TYPE  \
# 0           12             1        1               0               4
# 1           17             4        4               3               4
# 2           23             3        1               0               7
# 3           23             3        1               0               7
# 4           14             1        1               0               4
#
#      ...     DRIVER_COUNT_18YR  DRIVER_COUNT_19YR  DRIVER_COUNT_20YR  \
# ...

# %%
iris.describe()
# Out:
#        DISTR1:3939ICT  MUNICIPALITY  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  \
# count          3057.0   3057.000000  3057.000000  3057.000000  3057.000000
# mean             11.0   2288.839058     3.049722     4.132156  1394.375859
# std               0.0    115.896789     1.708123     1.971542  1188.208659
# min              11.0   2102.000000     1.000000     1.000000     0.000000
# 25%              11.0   2212.000000     2.000000     2.000000   824.000000
# 50%              11.0   2301.000000     3.000000     4.000000  1343.000000
# 75%              11.0   2403.000000     4.000000     6.000000  1735.000000
# max              11.0   2481.000000    11.000000     7.000000  9999.000000
#
#        HOUR_OF_DAY  ILLUMINATION      WEATHER  ROAD_CONDITION  COLLISION_TYPE  \
# count  3057.000000   3057.000000  3057.000000     3057.000000     3057.000000
# mean     13.654890      1.752044     1.543670        0.777233        4.200523
# ...

# %%
# check if duplicates exist
iris.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3027    False
# 3028    False
# 3029    False
# 3030    False
# 3031    False
# 3032    False
# 3033    False
# 3034    False
# 3035    False
# 3036    False
# 3037    False
# 3038    False
# 3039    False
# 3040    False
# 3041    False
# 3042    False
# 3043    False
# 3044    False
# 3045    False
# 3046    False
# 3047    False
# 3048    False
# 3049    False
# 3050    False
# 3051    False
# 3052    False
# 3053    False
# 3054    False
# 3055    False
# 3056    False
# ...

# %%
# Duplicates do not exist, so dropping duplicates  is unnecessary

# %%
# check the null values
iris.isnull()
# Out:
#       DISTR1:3939ICT  MUNICIPALITY  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  \
# 0              False         False        False        False        False
# 1              False         False        False        False        False
# 2              False         False        False        False        False
# 3              False         False        False        False        False
# 4              False         False        False        False        False
# 5              False         False        False        False        False
# 6              False         False        False        False        False
# 7              False         False        False        False        False
# 8              False         False        False        False        False
# 9              False         False        False        False        False
# 10             False         False        False        False        False
# 11             False         False        False        False        False
# ...

# %%
# check is space exists
iris['TIME_OF_DAY'].value_counts()
# Out:
# 9999    43
# 1130    18
# 1600    16
# 830     16
# 1420    16
# 1700    15
# 1630    15
# 1500    15
# 800     14
# 1230    12
# 1200    12
# 1400    12
# 900     11
# 730     11
# 1735    11
# 230     11
# 1710    10
# 1650    10
# 1300    10
# 1450    10
# 1440    10
# 1720    10
# 1530    10
# 1000    10
# 720     10
# 710     10
# 700     10
# 1135    10
# 1320     9
# 1125     9
#         ..
# 1356     1
# 457      1
# 629      1
# 1246     1
# 637      1
# 1242     1
# 801      1
# 747      1
# 1146     1
# 1148     1
# 739      1
# 1154     1
# 1156     1
# 737      1
# 1202     1
# 731      1
# 713      1
# 709      1
# 707      1
# 657      1
# 653      1
# 651      1
# 649      1
# 1226     1
# 1228     1
# 643      1
# 1236     1
# 1238     1
# 639      1
# 2004     1
# Name: TIME_OF_DAY, Length: 1086, dtype: int64

# %%
#check if extreme value exits
iris.describe().astype(np.int64).T
# Out:
#                       count  mean   std   min   25%   50%   75%   max
# DISTR1:3939ICT         3057    11     0    11    11    11    11    11
# MUNICIPALITY           3057  2288   115  2102  2212  2301  2403  2481
# CRASH_MONTH            3057     3     1     1     2     3     4    11
# DAY_OF_WEEK            3057     4     1     1     2     4     6     7
# TIME_OF_DAY            3057  1394  1188     0   824  1343  1735  9999
# HOUR_OF_DAY            3057    13    11     0     8    13    17    99
# ILLUMINATION           3057     1     1     1     1     1     3     8
# WEATHER                3057     1     1     1     1     1     1     9
# ROAD_CONDITION         3057     0     1     0     0     0     1     8
# COLLISION_TYPE         3057     4     2     0     1     4     7     9
# RELATION_TO_ROAD       3057     1     1     1     1     1     2     9
# PERSON_COUNT           3057     2     1     0     1     2     3    29
# ...

# %%
#the extreme values do not exist as per cloumn per row

# %%
#change the date formate
iris['TIME_OF_DAY']=pd.to_datetime(iris['TIME_OF_DAY'])

# %%
#check the format
iris.dtypes
# Out:
# DISTR1:3939ICT                   int64
# MUNICIPALITY                     int64
# CRASH_MONTH                      int64
# DAY_OF_WEEK                      int64
# TIME_OF_DAY             datetime64[ns]
# HOUR_OF_DAY                      int64
# ILLUMINATION                     int64
# WEATHER                          int64
# ROAD_CONDITION                   int64
# COLLISION_TYPE                   int64
# RELATION_TO_ROAD                 int64
# PERSON_COUNT                     int64
# VEHICLE_COUNT                    int64
# AUTOMOBILE_COUNT                 int64
# MOTORCYCLE_COUNT                 int64
# SMALL_TRUCK_COUNT                int64
# HEAVY_TRUCK_COUNT                int64
# SUV_COUNT                        int64
# VAN_COUNT                        int64
# BICYCLE_COUNT                    int64
# FATAL_COUNT                      int64
# INJURY_COUNT                     int64
# MIN_INJ_COUNT                    int64
# UNK_INJ_DEG_COUNT                int64
# ...

# %%
#Output the file
result=iris
result.to_csv('HW1.xlsx')

r=iris
r.to_xlsx('HW1.xlsx')
