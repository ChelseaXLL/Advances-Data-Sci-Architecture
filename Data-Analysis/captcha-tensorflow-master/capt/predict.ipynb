# %%
import time

import numpy as np
import tensorflow as tf

from cfg import MAX_CAPTCHA, CHAR_SET_LEN, model_path, save_model
from cnn_sys import crack_captcha_cnn, X, keep_prob
from gen_captcha import wrap_gen_captcha_text_and_image, gen_captcha_text_and_image
from utils import convert2gray, vec2text

def crack_captcha(captcha_image):

    output = crack_captcha_cnn()
    
    saver = tf.train.Saver()
   
    with tf.Session() as sess:
        #saver = tf.train.import_meta_graph("/Users/apple/work/crack/model/crack_capcha.model-10000-1500.meta")
        saver.restore(sess, tf.train.latest_checkpoint(model_path))
        predict = tf.argmax(tf.reshape(output, [-1, MAX_CAPTCHA, CHAR_SET_LEN]), 2)
        text_list = sess.run(predict, feed_dict={X: [captcha_image], keep_prob: 1})
        text = text_list[0].tolist()
        vector = np.zeros(MAX_CAPTCHA * CHAR_SET_LEN)
        i = 0
        for n in text:
            vector[i * CHAR_SET_LEN + n] = 1
            i += 1
        return vec2text(vector)
# Out:
# 验证码文本最长字符数 4
# CHAR_SET_LEN: 36
# model_path: C:\Users\josef\work/crack/model\crack_capcha.model

# %%
text,image = wrap_gen_captcha_text_and_image()
image = convert2gray(image)
image = image.flatten()/255
predict_text = crack_captcha(image)
print("正确: {}  预测: {}".format(text, predict_text))
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\josef\work/crack/model\crack_capcha.model-6300
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key Variable_20 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_13 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_2/Const_0_0, save_2/RestoreV2_13/tensor_names, save_2/RestoreV2_13/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-4-1ac3bfd9070e> in <module>()
#       2 image = convert2gray(image)
#       3 image = image.flatten()/255
# ----> 4 predict_text = crack_captcha(image)
#       5 print("正确: {}  预测: {}".format(text, predict_text))
#
# <ipython-input-1-5c0416e8fc1c> in crack_captcha(captcha_image)
#      17     with tf.Session() as sess:
#      18         #saver = tf.train.import_meta_graph("/Users/apple/work/crack/model/crack_capcha.model-10000-1500.meta")
# ---> 19         saver.restore(sess, tf.train.latest_checkpoint(model_path))
#      20         predict = tf.argmax(tf.reshape(output, [-1, MAX_CAPTCHA, CHAR_SET_LEN]), 2)
#      21         text_list = sess.run(predict, feed_dict={X: [captcha_image], keep_prob: 1})
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1684     if context.in_graph_mode():
#    1685       sess.run(self.saver_def.restore_op_name,
# -> 1686                {self.saver_def.filename_tensor_name: save_path})
#    1687     else:
#    1688       self._build_eager(save_path, build_save=False, build_restore=True)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# NotFoundError: Key Variable_20 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_13 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_2/Const_0_0, save_2/RestoreV2_13/tensor_names, save_2/RestoreV2_13/shape_and_slices)]]
#
# Caused by op 'save_2/RestoreV2_13', defined at:
#   File "C:\Users\josef\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\josef\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\josef\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-1ac3bfd9070e>", line 4, in <module>
#     predict_text = crack_captcha(image)
#   File "<ipython-input-1-5c0416e8fc1c>", line 15, in crack_captcha
#     saver = tf.train.Saver()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1239, in __init__
#     self.build()
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1248, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1284, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 765, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 428, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 268, in restore_op
#     [spec.tensor.dtype])[0])
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1113, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "C:\Users\josef\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Key Variable_20 not found in checkpoint
# 	 [[Node: save_2/RestoreV2_13 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_2/Const_0_0, save_2/RestoreV2_13/tensor_names, save_2/RestoreV2_13/shape_and_slices)]]

# %%
stime = time.time()
task_cnt = 1000
right_cnt = 0
        
for i in range(task_cnt):
    text, image = wrap_gen_captcha_text_and_image()
    image = convert2gray(image)
    image = image.flatten() / 255
    predict_text = crack_captcha(image)
    print("标记: {}  预测: {}".format(text, predict_text))
    if text == predict_text:
        right_cnt += 1
    else:
        pass    
    tf.Graph().as_default()
print('task:', task_cnt, ' cost time:', (time.time() - stime), 's')
print('right/total-----', right_cnt, '/', task_cnt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2175f73d6822> in <module>()
#       7     image = convert2gray(image)
#       8     image = image.flatten() / 255
# ----> 9     predict_text = crack_captcha(image)
#      10     print("标记: {}  预测: {}".format(text, predict_text))
#      11     if text == predict_text:
#
# <ipython-input-1-c48cb56f5a8c> in crack_captcha(captcha_image)
#      11 def crack_captcha(captcha_image):
#      12
# ---> 13     output = crack_captcha_cnn()
#      14
#      15     saver = tf.train.Saver()
#
# ~/Desktop/7390 final/cnn_sys.py in crack_captcha_cnn(w_alpha, b_alpha)
#      29     w_c1 = tf.Variable(w_alpha * tf.random_normal([3, 3, 1, 32]))
#      30     b_c1 = tf.Variable(b_alpha * tf.random_normal([32]))
# ---> 31     conv1 = tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(x, w_c1, strides=[1, 1, 1, 1], padding='SAME'), b_c1))
#      32     conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
#      33     conv1 = tf.nn.dropout(conv1, keep_prob)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name)
#     951         "Conv2D", input=input, filter=filter, strides=strides,
#     952         padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
# --> 953         data_format=data_format, dilations=dilations, name=name)
#     954     _result = _op.outputs[:]
#     955     _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     348       # Need to flatten all the arguments into a list.
#     349       # pylint: disable=protected-access
# --> 350       g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
#     351       # pylint: enable=protected-access
#     352     except AssertionError as e:
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _get_graph_from_inputs(op_input_list, graph)
#    5428         graph = graph_element.graph
#    5429       elif original_graph_element is not None:
# -> 5430         _assert_same_graph(original_graph_element, graph_element)
#    5431       elif graph_element.graph is not graph:
#    5432         raise ValueError("%s is not from the passed-in graph." % graph_element)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _assert_same_graph(original_item, item)
#    5364   if original_item.graph is not item.graph:
#    5365     raise ValueError("%s must be from the same graph as %s." % (item,
# -> 5366                                                                 original_item))
#    5367
#    5368
#
# ValueError: Tensor("Variable_2:0", shape=(3, 3, 1, 32), dtype=float32_ref) must be from the same graph as Tensor("Reshape_4:0", shape=(?, 60, 160, 1), dtype=float32).

# %%
def hack_function(sess, predict, captcha_image):
    """
    装载完成识别内容后，
    :param sess:
    :param predict:
    :param captcha_image:
    :return:
    """
    text_list = sess.run(predict, feed_dict={X: [captcha_image], keep_prob: 1})

    text = text_list[0].tolist()
    vector = np.zeros(MAX_CAPTCHA * CHAR_SET_LEN)
    i = 0
    for n in text:
        vector[i * CHAR_SET_LEN + n] = 1
        i += 1
    return vec2text(vector)


def batch_hack_captcha():
    """
    批量生成验证码，然后再批量进行识别
    :return:
    """

    # 定义预测计算图
    output = crack_captcha_cnn()
    predict = tf.argmax(tf.reshape(output, [-1, MAX_CAPTCHA, CHAR_SET_LEN]), 2)

    saver = tf.train.Saver()
    with tf.Session() as sess:
        #saver = tf.train.import_meta_graph(save_model + ".meta")
        saver.restore(sess, tf.train.latest_checkpoint(model_path))

        stime = time.time()
        task_cnt = 1000
        right_cnt = 0
        for i in range(task_cnt):
            text, image = wrap_gen_captcha_text_and_image()
            image = convert2gray(image)
            image = image.flatten() / 255
            predict_text = hack_function(sess, predict, image)
            if text == predict_text:
                right_cnt += 1
            else:
                print("标记: {}  预测: {}".format(text, predict_text))
                pass
                # print("标记: {}  预测: {}".format(text, predict_text))

        print('task:', task_cnt, ' cost time:', (time.time() - stime), 's')
        print('right/total-----', right_cnt, '/', task_cnt)


if __name__ == '__main__':
    batch_hack_captcha()
    print('end...')
# Out:
# INFO:tensorflow:Restoring parameters from /Users/apple/work/crack/model/crack_capcha.model-18000
# 标记: JNZ3  预测: RMGA
# 标记: 3B2Z  预测: RMGA
# 标记: QZEQ  预测: RMGA
# 标记: QKL9  预测: RMGA
# 标记: J5WT  预测: RMGA
# 标记: Q91K  预测: RMGA
# 标记: 6N3C  预测: RMGA
# 标记: HBLU  预测: RMGA
# 标记: 4KB6  预测: RMGA
# 标记: 5NOS  预测: RMGA
# 标记: JN0J  预测: RMGA
# 标记: N81T  预测: RMGA
# 标记: 7GEL  预测: RMGA
# 标记: 8JJE  预测: RMGA
# 标记: CTRU  预测: RMGA
# 标记: 2BAO  预测: RMGA
# 标记: 3Q31  预测: RMGA
# 标记: BOKZ  预测: RMGA
# 标记: GRG1  预测: RMGA
# 标记: 279T  预测: RMGA
# 标记: ARXU  预测: RMGA
# 标记: GQNZ  预测: RMGA
# 标记: Q4D2  预测: RMGA
# 标记: HLU0  预测: RMGA
# 标记: F228  预测: RMGA
# 标记: DSM3  预测: RMGA
# 标记: 4WVH  预测: RMGA
# 标记: WT3I  预测: RMGA
# 标记: MIG7  预测: RMGA
# 标记: 34AR  预测: RMGA
# 标记: 3525  预测: RMGA
# 标记: T24P  预测: RMGA
# 标记: PYDK  预测: RMGA
# 标记: 37PY  预测: RMGA
# 标记: WMZ3  预测: RMGA
# 标记: 88WH  预测: RMGA
# 标记: 8WCS  预测: RMGA
# 标记: 6PGO  预测: RMGA
# 标记: PA28  预测: RMGA
# 标记: LU5W  预测: RMGA
# 标记: 22NL  预测: RMGA
# 标记: KQQ8  预测: RMGA
# 标记: 5G2C  预测: RMGA
# 标记: DC7D  预测: RMGA
# 标记: RJ5T  预测: RMGA
# 标记: LED3  预测: RMGA
# 标记: T4I0  预测: RMGA
# 标记: KWRR  预测: RMGA
# 标记: 8Q27  预测: RMGA
# 标记: W0OP  预测: RMGA
# 标记: X8DC  预测: RMGA
# 标记: 3IIN  预测: RMGA
# 标记: YH3S  预测: RMGA
# 标记: FMLL  预测: RMGA
# 标记: KRBE  预测: RMGA
# 标记: ZJSK  预测: RMGA
# 标记: 3QRX  预测: RMGA
# 标记: JELU  预测: RMGA
# 标记: 6O7T  预测: RMGA
# 标记: UYAT  预测: RMGA
# 标记: 4XAW  预测: RMGA
# 标记: U8Q6  预测: RMGA
# 标记: 15TV  预测: RMGA
# 标记: RBSZ  预测: RMGA
# 标记: RE9C  预测: RMGA
# 标记: D8TL  预测: RMGA
# 标记: Q63Y  预测: RMGA
# 标记: O1M7  预测: RMGA
# 标记: HEFL  预测: RMGA
# 标记: ESQ6  预测: RMGA
# 标记: 1KVD  预测: RMGA
# 标记: UILR  预测: RMGA
# 标记: LSDG  预测: RMGA
# 标记: LHX9  预测: RMGA
# 标记: NYWM  预测: RMGA
# 标记: 77V7  预测: RMGA
# 标记: M25V  预测: RMGA
# 标记: C9VE  预测: RMGA
# 标记: BBEX  预测: RMGA
# 标记: BU7X  预测: RMGA
# 标记: 6OC8  预测: RMGA
# 标记: ARUT  预测: RMGA
# 标记: RKG3  预测: RMGA
# 标记: LYW5  预测: RMGA
# 标记: 7CBI  预测: RMGA
# 标记: XS14  预测: RMGA
# 标记: LAAA  预测: RMGA
# 标记: QOZ0  预测: RMGA
# 标记: IJCZ  预测: RMGA
# 标记: FPHZ  预测: RMGA
# 标记: XM6X  预测: RMGA
# 标记: MEYC  预测: RMGA
# 标记: X6RD  预测: RMGA
# 标记: 76LJ  预测: RMGA
# 标记: BPAC  预测: RMGA
# 标记: YCBI  预测: RMGA
# 标记: DJ0H  预测: RMGA
# 标记: 034Q  预测: RMGA
# 标记: CUL9  预测: RMGA
# 标记: G1OO  预测: RMGA
# 标记: 3ENN  预测: RMGA
# 标记: VIC9  预测: RMGA
# 标记: ONO2  预测: RMGA
# 标记: RYAS  预测: RMGA
# 标记: 95EP  预测: RMGA
# 标记: Y4YX  预测: RMGA
# 标记: L75M  预测: RMGA
# 标记: W3O6  预测: RMGA
# 标记: 5M8O  预测: RMGA
# 标记: 4P7G  预测: RMGA
# 标记: 6OJN  预测: RMGA
# 标记: 41R4  预测: RMGA
# 标记: 9VB6  预测: RMGA
# 标记: XSR6  预测: RMGA
# 标记: QPS7  预测: RMGA
# 标记: HZ5E  预测: RMGA
# 标记: Y64U  预测: RMGA
# 标记: NQUF  预测: RMGA
# 标记: Y1I1  预测: RMGA
# 标记: 1VU9  预测: RMGA
# 标记: U2DZ  预测: RMGA
# 标记: GJFS  预测: RMGA
# 标记: 8QAN  预测: RMGA
# 标记: LO0I  预测: RMGA
# 标记: Z5JL  预测: RMGA
# 标记: 3OO7  预测: RMGA
# 标记: OE6D  预测: RMGA
# 标记: E98A  预测: RMGA
# 标记: MGO0  预测: RMGA
# 标记: O46F  预测: RMGA
# 标记: ULYJ  预测: RMGA
# 标记: TB8O  预测: RMGA
# 标记: XXUO  预测: RMGA
# 标记: XKJD  预测: RMGA
# 标记: 01MJ  预测: RMGA
# 标记: DLF6  预测: RMGA
# 标记: NSMG  预测: RMGA
# 标记: H4XW  预测: RMGA
# 标记: F7FB  预测: RMGA
# 标记: UDE1  预测: RMGA
# 标记: S7BO  预测: RMGA
# 标记: ZCI9  预测: RMGA
# 标记: F5CW  预测: RMGA
# 标记: ZN57  预测: RMGA
# 标记: Q9OR  预测: RMGA
# 标记: 2M7Z  预测: RMGA
# 标记: MTCM  预测: RMGA
# 标记: D5WQ  预测: RMGA
# 标记: XS8Y  预测: RMGA
# 标记: KBJD  预测: RMGA
# 标记: QYK3  预测: RMGA
# 标记: ZF01  预测: RMGA
# 标记: 7603  预测: RMGA
# 标记: 53IL  预测: RMGA
# 标记: 3FBR  预测: RMGA
# 标记: 881F  预测: RMGA
# 标记: 3P9Q  预测: RMGA
# 标记: 87TP  预测: RMGA
# 标记: XELY  预测: RMGA
# 标记: XIST  预测: RMGA
# 标记: WHXG  预测: RMGA
# 标记: 4R00  预测: RMGA
# 标记: QKFW  预测: RMGA
# 标记: MY85  预测: RMGA
# 标记: KHU2  预测: RMGA
# 标记: PNFL  预测: RMGA
# 标记: HNZX  预测: RMGA
# 标记: U0H4  预测: RMGA
# 标记: 3M2U  预测: RMGA
# 标记: QXIV  预测: RMGA
# 标记: FKTC  预测: RMGA
# 标记: 0VYI  预测: RMGA
# 标记: LI6Q  预测: RMGA
# 标记: QGW7  预测: RMGA
# 标记: 927P  预测: RMGA
# 标记: 8WBY  预测: RMGA
# 标记: 4AYH  预测: RMGA
# 标记: 21UK  预测: RMGA
# 标记: V79H  预测: RMGA
# 标记: 9VN8  预测: RMGA
# 标记: ANQ4  预测: RMGA
# 标记: 6TLY  预测: RMGA
# 标记: MJNT  预测: RMGA
# 标记: KVXG  预测: RMGA
# 标记: DON0  预测: RMGA
# 标记: 5Y9Z  预测: RMGA
# 标记: SEZF  预测: RMGA
# 标记: NN66  预测: RMGA
# 标记: F62C  预测: RMGA
# 标记: KXBA  预测: RMGA
# 标记: T85N  预测: RMGA
# 标记: R4S0  预测: RMGA
# 标记: 9FNB  预测: RMGA
# 标记: 2Y5X  预测: RMGA
# 标记: NJKF  预测: RMGA
# 标记: CB7J  预测: RMGA
# 标记: GGHW  预测: RMGA
# 标记: BFKM  预测: RMGA
# 标记: Y59I  预测: RMGA
# 标记: 786S  预测: RMGA
# 标记: D6UC  预测: RMGA
# 标记: DG6E  预测: RMGA
# 标记: 6XTI  预测: RMGA
# 标记: Q5TA  预测: RMGA
# 标记: TF4B  预测: RMGA
# 标记: C0DH  预测: RMGA
# 标记: CF1F  预测: RMGA
# 标记: Q9T8  预测: RMGA
# 标记: PK6V  预测: RMGA
# 标记: MGMR  预测: RMGA
# 标记: Q26Z  预测: RMGA
# 标记: SBHU  预测: RMGA
# 标记: U8YN  预测: RMGA
# 标记: PJ9J  预测: RMGA
# 标记: EABO  预测: RMGA
# 标记: MGBN  预测: RMGA
# 标记: R2OX  预测: RMGA
# 标记: WS4G  预测: RMGA
# 标记: QNY0  预测: RMGA
# 标记: Q2QJ  预测: RMGA
# 标记: GH15  预测: RMGA
# 标记: ADTD  预测: RMGA
# 标记: EJ31  预测: RMGA
# 标记: GP7J  预测: RMGA
# 标记: 7C10  预测: RMGA
# 标记: GH1Q  预测: RMGA
# 标记: SEGE  预测: RMGA
# 标记: DIUV  预测: RMGA
# 标记: OIP7  预测: RMGA
# 标记: FFN4  预测: RMGA
# 标记: LL76  预测: RMGA
# 标记: ISE6  预测: RMGA
# 标记: INEB  预测: RMGA
# 标记: Z0U6  预测: RMGA
# 标记: KVGD  预测: RMGA
# 标记: 61AZ  预测: RMGA
# 标记: DATB  预测: RMGA
# 标记: QLEG  预测: RMGA
# 标记: VVY8  预测: RMGA
# 标记: DPZ0  预测: RMGA
# 标记: 5Z8B  预测: RMGA
# 标记: MH6D  预测: RMGA
# 标记: P9OU  预测: RMGA
# 标记: FDEF  预测: RMGA
# 标记: 5SM3  预测: RMGA
# 标记: 97OX  预测: RMGA
# 标记: 65N2  预测: RMGA
# 标记: G0A9  预测: RMGA
# 标记: NV38  预测: RMGA
# 标记: X4MR  预测: RMGA
# 标记: 9IKY  预测: RMGA
# 标记: 0MKG  预测: RMGA
# 标记: 81GM  预测: RMGA
# 标记: 5NYE  预测: RMGA
# 标记: I1IR  预测: RMGA
# 标记: SYWN  预测: RMGA
# 标记: Y2XV  预测: RMGA
# 标记: R3Y1  预测: RMGA
# 标记: D35M  预测: RMGA
# 标记: 8HW4  预测: RMGA
# 标记: 8F4H  预测: RMGA
# 标记: B6MN  预测: RMGA
# 标记: FTAQ  预测: RMGA
# 标记: XYR2  预测: RMGA
# 标记: 5A3T  预测: RMGA
# 标记: H953  预测: RMGA
# 标记: SM91  预测: RMGA
# 标记: 8ZHQ  预测: RMGA
# 标记: I22H  预测: RMGA
# 标记: FOG6  预测: RMGA
# 标记: A20E  预测: RMGA
# 标记: P3AP  预测: RMGA
# 标记: BKY8  预测: RMGA
# 标记: 5KUQ  预测: RMGA
# 标记: WZ8J  预测: RMGA
# 标记: R28V  预测: RMGA
# 标记: 0MKB  预测: RMGA
# 标记: 9PKY  预测: RMGA
# 标记: VADY  预测: RMGA
# 标记: Z4ZV  预测: RMGA
# 标记: UPWO  预测: RMGA
# 标记: 2R4U  预测: RMGA
# 标记: PAKF  预测: RMGA
# 标记: 9PNP  预测: RMGA
# 标记: QTX7  预测: RMGA
# 标记: FGL0  预测: RMGA
# 标记: 90AK  预测: RMGA
# 标记: P86B  预测: RMGA
# 标记: OJ89  预测: RMGA
# 标记: NXEZ  预测: RMGA
# 标记: R3ZT  预测: RMGA
# 标记: 9W51  预测: RMGA
# 标记: 5ZJG  预测: RMGA
# 标记: 9FOC  预测: RMGA
# 标记: N610  预测: RMGA
# 标记: KJII  预测: RMGA
# 标记: R8EL  预测: RMGA
# 标记: Z5H7  预测: RMGA
# 标记: 67M7  预测: RMGA
# 标记: 8DJL  预测: RMGA
# 标记: D2VW  预测: RMGA
# 标记: TGWT  预测: RMGA
# 标记: QH20  预测: RMGA
# 标记: X1H9  预测: RMGA
# 标记: 4ARC  预测: RMGA
# 标记: 815Q  预测: RMGA
# 标记: L8E5  预测: RMGA
# 标记: ETQL  预测: RMGA
# 标记: 35OS  预测: RMGA
# 标记: 2TPB  预测: RMGA
# 标记: JN7A  预测: RMGA
# 标记: ERF7  预测: RMGA
# 标记: L4WX  预测: RMGA
# 标记: 03ER  预测: RMGA
# 标记: HIS5  预测: RMGA
# 标记: 44P4  预测: RMGA
# 标记: RKK0  预测: RMGA
# 标记: VIK3  预测: RMGA
# 标记: 92WU  预测: RMGA
# 标记: 37NL  预测: RMGA
# 标记: KOL5  预测: RMGA
# 标记: JHN9  预测: RMGA
# 标记: 4IRD  预测: RMGA
# 标记: 0BRZ  预测: RMGA
# 标记: 1G5N  预测: RMGA
# 标记: JZKZ  预测: RMGA
# 标记: DLP4  预测: RMGA
# 标记: XCUD  预测: RMGA
# 标记: 3VB9  预测: RMGA
# 标记: IMWZ  预测: RMGA
# 标记: 3K4Y  预测: RMGA
# 标记: R2JS  预测: RMGA
# 标记: 985E  预测: RMGA
# 标记: Y3EM  预测: RMGA
# 标记: 0KTT  预测: RMGA
# 标记: 4YJ8  预测: RMGA
# 标记: U4Z8  预测: RMGA
# 标记: QMZL  预测: RMGA
# 标记: TKTI  预测: RMGA
# 标记: 9COF  预测: RMGA
# 标记: D8E3  预测: RMGA
# 标记: SXYK  预测: RMGA
# 标记: B1F5  预测: RMGA
# 标记: U357  预测: RMGA
# 标记: 2PEQ  预测: RMGA
# 标记: EY47  预测: RMGA
# 标记: SB3T  预测: RMGA
# 标记: 2BMS  预测: RMGA
# 标记: R0ZQ  预测: RMGA
# 标记: DQ3V  预测: RMGA
# 标记: UZ91  预测: RMGA
# 标记: TYJW  预测: RMGA
# 标记: 6DIC  预测: RMGA
# 标记: LLYV  预测: RMGA
# 标记: 5DJG  预测: RMGA
# 标记: A48W  预测: RMGA
# 标记: RRY3  预测: RMGA
# 标记: IG22  预测: RMGA
# 标记: 796V  预测: RMGA
# 标记: CL95  预测: RMGA
# 标记: 8YI0  预测: RMGA
# 标记: F4KL  预测: RMGA
# 标记: DBDU  预测: RMGA
# 标记: DD3J  预测: RMGA
# 标记: WOTN  预测: RMGA
# 标记: NO8S  预测: RMGA
# 标记: YHLK  预测: RMGA
# 标记: 0BM4  预测: RMGA
# 标记: 62MQ  预测: RMGA
# 标记: OG7W  预测: RMGA
# 标记: Z4KC  预测: RMGA
# 标记: S19E  预测: RMGA
# 标记: W60B  预测: RMGA
# 标记: U2D2  预测: RMGA
# 标记: 4Y06  预测: RMGA
# 标记: 4ZAR  预测: RMGA
# 标记: HQNX  预测: RMGA
# 标记: LJA6  预测: RMGA
# 标记: QI2E  预测: RMGA
# 标记: D9E0  预测: RMGA
# 标记: OV17  预测: RMGA
# 标记: NCDP  预测: RMGA
# 标记: KQGH  预测: RMGA
# 标记: RTQJ  预测: RMGA
# 标记: RRZA  预测: RMGA
# 标记: LSS1  预测: RMGA
# 标记: UNSO  预测: RMGA
# 标记: KGDU  预测: RMGA
# 标记: 5EHC  预测: RMGA
# 标记: SNTZ  预测: RMGA
# 标记: USIS  预测: RMGA
# 标记: WV4N  预测: RMGA
# 标记: K047  预测: RMGA
# 标记: 6MTT  预测: RMGA
# 标记: F95D  预测: RMGA
# 标记: SV6H  预测: RMGA
# 标记: UUJ4  预测: RMGA
# 标记: 6QGN  预测: RMGA
# 标记: 7TTM  预测: RMGA
# 标记: YF16  预测: RMGA
# 标记: 5VX0  预测: RMGA
# 标记: W60E  预测: RMGA
# 标记: CKXJ  预测: RMGA
# 标记: XSC5  预测: RMGA
# 标记: JB03  预测: RMGA
# 标记: YM5M  预测: RMGA
# 标记: NAKF  预测: RMGA
# 标记: 1B7I  预测: RMGA
# 标记: IC9O  预测: RMGA
# 标记: WIS6  预测: RMGA
# 标记: VF7E  预测: RMGA
# 标记: D7I2  预测: RMGA
# 标记: P7KQ  预测: RMGA
# 标记: 2P8G  预测: RMGA
# 标记: 7DS4  预测: RMGA
# 标记: C5KT  预测: RMGA
# 标记: ZDOS  预测: RMGA
# 标记: IYS8  预测: RMGA
# 标记: 9VI2  预测: RMGA
# 标记: HI7P  预测: RMGA
# 标记: 1Y3Z  预测: RMGA
# 标记: 6JZO  预测: RMGA
# 标记: NYN9  预测: RMGA
# 标记: IVRD  预测: RMGA
# 标记: RPV2  预测: RMGA
# 标记: B08N  预测: RMGA
# 标记: LCSB  预测: RMGA
# 标记: KAM2  预测: RMGA
# 标记: 4VBL  预测: RMGA
# 标记: CVY2  预测: RMGA
# 标记: 81IW  预测: RMGA
# 标记: R5ND  预测: RMGA
# 标记: AOX5  预测: RMGA
# 标记: 0XH7  预测: RMGA
# 标记: SEUA  预测: RMGA
# 标记: AY7I  预测: RMGA
# 标记: OX6O  预测: RMGA
# 标记: 6OYV  预测: RMGA
# 标记: RA82  预测: RMGA
# 标记: TQOX  预测: RMGA
# 标记: 42WK  预测: RMGA
# 标记: 98ZX  预测: RMGA
# 标记: LE63  预测: RMGA
# 标记: DZ85  预测: RMGA
# 标记: NMZM  预测: RMGA
# 标记: 3QMI  预测: RMGA
# 标记: VA9X  预测: RMGA
# 标记: 7B2M  预测: RMGA
# 标记: G1FK  预测: RMGA
# 标记: SZ62  预测: RMGA
# 标记: T2W7  预测: RMGA
# 标记: XRIH  预测: RMGA
# 标记: 6XS5  预测: RMGA
# 标记: Q4XI  预测: RMGA
# 标记: SZJB  预测: RMGA
# 标记: J58R  预测: RMGA
# 标记: RN5V  预测: RMGA
# 标记: XXRB  预测: RMGA
# 标记: 4TAY  预测: RMGA
# 标记: DEKH  预测: RMGA
# 标记: T21C  预测: RMGA
# 标记: VNK7  预测: RMGA
# 标记: 3M7C  预测: RMGA
# 标记: S087  预测: RMGA
# 标记: I0Q5  预测: RMGA
# 标记: QVW3  预测: RMGA
# 标记: 120A  预测: RMGA
# 标记: NSN3  预测: RMGA
# 标记: BHBK  预测: RMGA
# 标记: OWEY  预测: RMGA
# 标记: IC9J  预测: RMGA
# 标记: S54X  预测: RMGA
# 标记: NOGE  预测: RMGA
# 标记: CLEX  预测: RMGA
# 标记: GFLV  预测: RMGA
# 标记: SJUC  预测: RMGA
# 标记: 77TB  预测: RMGA
# 标记: FGTV  预测: RMGA
# 标记: JOJE  预测: RMGA
# 标记: K1UY  预测: RMGA
# 标记: QCWQ  预测: RMGA
# 标记: DA18  预测: RMGA
# 标记: 5K5S  预测: RMGA
# 标记: 6U59  预测: RMGA
# 标记: NBMI  预测: RMGA
# 标记: KW5K  预测: RMGA
# 标记: F1CD  预测: RMGA
# 标记: JM8N  预测: RMGA
# 标记: NYTV  预测: RMGA
# 标记: 0RLG  预测: RMGA
# 标记: L3ST  预测: RMGA
# 标记: WM6C  预测: RMGA
# 标记: P84V  预测: RMGA
# 标记: FJW3  预测: RMGA
# 标记: 6IMT  预测: RMGA
# 标记: R6E8  预测: RMGA
# 标记: 73K4  预测: RMGA
# 标记: C2RT  预测: RMGA
# 标记: G7A2  预测: RMGA
# 标记: 02C3  预测: RMGA
# 标记: 3N7R  预测: RMGA
# 标记: BMU5  预测: RMGA
# 标记: 88A8  预测: RMGA
# 标记: BG0Y  预测: RMGA
# 标记: P94S  预测: RMGA
# 标记: BFTP  预测: RMGA
# 标记: S0HX  预测: RMGA
# 标记: S2T8  预测: RMGA
# 标记: 8342  预测: RMGA
# 标记: WZBV  预测: RMGA
# 标记: 4E0Y  预测: RMGA
# 标记: T9IL  预测: RMGA
# 标记: FK7M  预测: RMGA
# 标记: IC9B  预测: RMGA
# 标记: E685  预测: RMGA
# 标记: OX54  预测: RMGA
# 标记: 6RIN  预测: RMGA
# 标记: 5GCK  预测: RMGA
# 标记: NANO  预测: RMGA
# 标记: XU04  预测: RMGA
# 标记: 82XQ  预测: RMGA
# 标记: 390R  预测: RMGA
# 标记: K6H4  预测: RMGA
# 标记: 4X9E  预测: RMGA
# 标记: V7NZ  预测: RMGA
# 标记: ZARK  预测: RMGA
# 标记: 97MA  预测: RMGA
# 标记: KCYB  预测: RMGA
# 标记: 606S  预测: RMGA
# 标记: 605C  预测: RMGA
# 标记: F5C6  预测: RMGA
# 标记: 6ML0  预测: RMGA
# 标记: EJG3  预测: RMGA
# 标记: EOQJ  预测: RMGA
# 标记: RLZA  预测: RMGA
# 标记: CG4A  预测: RMGA
# 标记: HCMW  预测: RMGA
# 标记: D9HD  预测: RMGA
# 标记: 7I6A  预测: RMGA
# 标记: 1WCS  预测: RMGA
# 标记: S25P  预测: RMGA
# 标记: GSN0  预测: RMGA
# 标记: BET0  预测: RMGA
# 标记: QULD  预测: RMGA
# 标记: 2PA9  预测: RMGA
# 标记: JY95  预测: RMGA
# 标记: NGF0  预测: RMGA
# 标记: 6VXJ  预测: RMGA
# 标记: 07OY  预测: RMGA
# 标记: KF2M  预测: RMGA
# 标记: N172  预测: RMGA
# 标记: 4EWI  预测: RMGA
# 标记: VKB2  预测: RMGA
# 标记: S2IY  预测: RMGA
# 标记: EPZH  预测: RMGA
# 标记: IFHM  预测: RMGA
# 标记: Q09E  预测: RMGA
# 标记: PNM7  预测: RMGA
# 标记: SOI4  预测: RMGA
# 标记: M9PK  预测: RMGA
# 标记: F143  预测: RMGA
# 标记: QHD4  预测: RMGA
# 标记: CTAE  预测: RMGA
# 标记: F9JU  预测: RMGA
# 标记: 3RVR  预测: RMGA
# 标记: AA1C  预测: RMGA
# 标记: YTAP  预测: RMGA
# 标记: KEPU  预测: RMGA
# 标记: QEPW  预测: RMGA
# 标记: MZ20  预测: RMGA
# 标记: VVVW  预测: RMGA
# 标记: BNQ2  预测: RMGA
# 标记: P1L2  预测: RMGA
# 标记: K7QD  预测: RMGA
# 标记: TJLV  预测: RMGA
# 标记: 9N77  预测: RMGA
# 标记: WUFO  预测: RMGA
# 标记: 1AKM  预测: RMGA
# 标记: PMTP  预测: RMGA
# 标记: K9CK  预测: RMGA
# 标记: 71Z8  预测: RMGA
# 标记: S4I6  预测: RMGA
# 标记: T6HI  预测: RMGA
# 标记: 1G4Y  预测: RMGA
# 标记: ICLQ  预测: RMGA
# 标记: XL0H  预测: RMGA
# 标记: DMCO  预测: RMGA
# 标记: NHSZ  预测: RMGA
# 标记: S17R  预测: RMGA
# 标记: WX1V  预测: RMGA
# 标记: IBZ9  预测: RMGA
# 标记: 3884  预测: RMGA
# 标记: 0E45  预测: RMGA
# 标记: 4O8P  预测: RMGA
# 标记: L7MT  预测: RMGA
# 标记: D6LH  预测: RMGA
# 标记: G5BG  预测: RMGA
# 标记: PUCA  预测: RMGA
# 标记: IBT4  预测: RMGA
# 标记: S9C0  预测: RMGA
# 标记: KT6E  预测: RMGA
# 标记: VND9  预测: RMGA
# 标记: RNHS  预测: RMGA
# 标记: SDY9  预测: RMGA
# 标记: 95TF  预测: RMGA
# 标记: ZPLU  预测: RMGA
# 标记: WJ0T  预测: RMGA
# 标记: DTH3  预测: RMGA
# 标记: T9RB  预测: RMGA
# 标记: N7B7  预测: RMGA
# 标记: B26C  预测: RMGA
# 标记: L7QH  预测: RMGA
# 标记: FS3Y  预测: RMGA
# 标记: 4VXK  预测: RMGA
# 标记: WH6K  预测: RMGA
# 标记: W2N1  预测: RMGA
# 标记: 402P  预测: RMGA
# 标记: O6GA  预测: RMGA
# 标记: 8SZU  预测: RMGA
# 标记: Y81I  预测: RMGA
# 标记: 0AO4  预测: RMGA
# 标记: 5RHL  预测: RMGA
# 标记: P46V  预测: RMGA
# 标记: 0C9B  预测: RMGA
# 标记: KO81  预测: RMGA
# 标记: IR2Q  预测: RMGA
# 标记: 4D4V  预测: RMGA
# 标记: 4RAJ  预测: RMGA
# 标记: FEBA  预测: RMGA
# 标记: NP1P  预测: RMGA
# 标记: 07JH  预测: RMGA
# 标记: 656J  预测: RMGA
# 标记: EAOK  预测: RMGA
# 标记: THBR  预测: RMGA
# 标记: JL5T  预测: RMGA
# 标记: FQJL  预测: RMGA
# 标记: FX1R  预测: RMGA
# 标记: NG2H  预测: RMGA
# 标记: 6IWY  预测: RMGA
# 标记: RHLL  预测: RMGA
# 标记: PBPQ  预测: RMGA
# 标记: 6F4Y  预测: RMGA
# 标记: EQ8G  预测: RMGA
# 标记: SQEV  预测: RMGA
# 标记: S0NL  预测: RMGA
# 标记: GQZZ  预测: RMGA
# 标记: 46JZ  预测: RMGA
# 标记: QHTK  预测: RMGA
# 标记: 8XT3  预测: RMGA
# 标记: SITH  预测: RMGA
# 标记: 1PSL  预测: RMGA
# 标记: KC5R  预测: RMGA
# 标记: PBA5  预测: RMGA
# 标记: B9EL  预测: RMGA
# 标记: 67RS  预测: RMGA
# 标记: KE3D  预测: RMGA
# 标记: 7PV1  预测: RMGA
# 标记: 94M6  预测: RMGA
# 标记: 7T45  预测: RMGA
# 标记: A7FJ  预测: RMGA
# 标记: QPOQ  预测: RMGA
# 标记: SI2Y  预测: RMGA
# 标记: C47S  预测: RMGA
# 标记: VFTB  预测: RMGA
# 标记: WMIQ  预测: RMGA
# 标记: M6ME  预测: RMGA
# 标记: SF3Z  预测: RMGA
# 标记: E3S2  预测: RMGA
# 标记: IH6M  预测: RMGA
# 标记: 722V  预测: RMGA
# 标记: BI9M  预测: RMGA
# 标记: UNV3  预测: RMGA
# 标记: HGYN  预测: RMGA
# 标记: 7YGD  预测: RMGA
# 标记: TCCD  预测: RMGA
# 标记: W69J  预测: RMGA
# 标记: 3S41  预测: RMGA
# 标记: BKAR  预测: RMGA
# 标记: MLNZ  预测: RMGA
# 标记: GK3I  预测: RMGA
# 标记: ZXV9  预测: RMGA
# 标记: 1R5T  预测: RMGA
# 标记: ZK0M  预测: RMGA
# 标记: N660  预测: RMGA
# 标记: PQSA  预测: RMGA
# 标记: LKQR  预测: RMGA
# 标记: 6J9I  预测: RMGA
# 标记: TGN3  预测: RMGA
# 标记: 8IB1  预测: RMGA
# 标记: XHWW  预测: RMGA
# 标记: 915P  预测: RMGA
# 标记: SYVC  预测: RMGA
# 标记: O9SO  预测: RMGA
# 标记: 1AET  预测: RMGA
# 标记: 8UMY  预测: RMGA
# 标记: ONWL  预测: RMGA
# 标记: MTRD  预测: RMGA
# 标记: 21W6  预测: RMGA
# 标记: 1XDV  预测: RMGA
# 标记: NPWJ  预测: RMGA
# 标记: 9D7X  预测: RMGA
# 标记: 9M5Y  预测: RMGA
# 标记: JZAR  预测: RMGA
# 标记: QYU3  预测: RMGA
# 标记: 2E14  预测: RMGA
# 标记: 5NL0  预测: RMGA
# 标记: AC4V  预测: RMGA
# 标记: N6JP  预测: RMGA
# 标记: RYTD  预测: RMGA
# 标记: TMRY  预测: RMGA
# 标记: VS6K  预测: RMGA
# 标记: 2CST  预测: RMGA
# 标记: ZF5R  预测: RMGA
# 标记: HNX8  预测: RMGA
# 标记: UW7H  预测: RMGA
# 标记: RGI9  预测: RMGA
# 标记: 0722  预测: RMGA
# 标记: L0FL  预测: RMGA
# 标记: MVUW  预测: RMGA
# 标记: O57X  预测: RMGA
# 标记: POO3  预测: RMGA
# 标记: S8GB  预测: RMGA
# 标记: 5YRM  预测: RMGA
# 标记: LK9N  预测: RMGA
# 标记: LAFW  预测: RMGA
# 标记: 7VME  预测: RMGA
# 标记: EH6O  预测: RMGA
# 标记: 1E2U  预测: RMGA
# 标记: ER0S  预测: RMGA
# 标记: 4FV1  预测: RMGA
# 标记: W6YD  预测: RMGA
# 标记: 7D4H  预测: RMGA
# 标记: SD3B  预测: RMGA
# 标记: FVJ7  预测: RMGA
# 标记: Y9LW  预测: RMGA
# 标记: XIHI  预测: RMGA
# 标记: LJCN  预测: RMGA
# 标记: 7PMD  预测: RMGA
# 标记: VF24  预测: RMGA
# 标记: A9OQ  预测: RMGA
# 标记: UKQ8  预测: RMGA
# 标记: 5PXL  预测: RMGA
# 标记: 7QB9  预测: RMGA
# 标记: U4HS  预测: RMGA
# 标记: CWQ2  预测: RMGA
# 标记: 02V8  预测: RMGA
# 标记: RM2C  预测: RMGA
# 标记: 7WY7  预测: RMGA
# 标记: JOXP  预测: RMGA
# 标记: 737Z  预测: RMGA
# 标记: HV3L  预测: RMGA
# 标记: D9NP  预测: RMGA
# 标记: JXT4  预测: RMGA
# 标记: BZ1W  预测: RMGA
# 标记: 915B  预测: RMGA
# 标记: DUKR  预测: RMGA
# 标记: FFA8  预测: RMGA
# 标记: YPW0  预测: RMGA
# 标记: 1D3X  预测: RMGA
# 标记: D5M5  预测: RMGA
# 标记: QEOR  预测: RMGA
# 标记: TAPO  预测: RMGA
# 标记: SJS5  预测: RMGA
# 标记: FW49  预测: RMGA
# 标记: TJTB  预测: RMGA
# 标记: 87O3  预测: RMGA
# 标记: 17B1  预测: RMGA
# 标记: ZWLE  预测: RMGA
# 标记: 7MYX  预测: RMGA
# 标记: 6UVQ  预测: RMGA
# 标记: 60FS  预测: RMGA
# 标记: BDZ5  预测: RMGA
# 标记: 14OI  预测: RMGA
# 标记: 3RMH  预测: RMGA
# 标记: BD48  预测: RMGA
# 标记: EGW4  预测: RMGA
# 标记: IZ7T  预测: RMGA
# 标记: N74Y  预测: RMGA
# 标记: U778  预测: RMGA
# 标记: LRKO  预测: RMGA
# 标记: YLGV  预测: RMGA
# 标记: 88JJ  预测: RMGA
# 标记: N2IZ  预测: RMGA
# 标记: O2JD  预测: RMGA
# 标记: RYTI  预测: RMGA
# 标记: I0VM  预测: RMGA
# 标记: LK14  预测: RMGA
# 标记: DL4A  预测: RMGA
# 标记: IPK7  预测: RMGA
# 标记: MNJ3  预测: RMGA
# 标记: SG72  预测: RMGA
# 标记: CMM8  预测: RMGA
# 标记: BKRX  预测: RMGA
# 标记: Y7JZ  预测: RMGA
# 标记: XMBR  预测: RMGA
# 标记: 307H  预测: RMGA
# 标记: GSKH  预测: RMGA
# 标记: OJPU  预测: RMGA
# 标记: 47V8  预测: RMGA
# 标记: NGRP  预测: RMGA
# 标记: A45K  预测: RMGA
# 标记: KBEC  预测: RMGA
# 标记: T6R3  预测: RMGA
# 标记: GMRH  预测: RMGA
# 标记: VKNS  预测: RMGA
# 标记: 4X7M  预测: RMGA
# 标记: 4WMZ  预测: RMGA
# 标记: LOEZ  预测: RMGA
# 标记: QKT6  预测: RMGA
# 标记: L397  预测: RMGA
# 标记: NW6Y  预测: RMGA
# 标记: H1UO  预测: RMGA
# 标记: CA3J  预测: RMGA
# 标记: B1MG  预测: RMGA
# 标记: 0V86  预测: RMGA
# 标记: 9YEY  预测: RMGA
# 标记: LDKD  预测: RMGA
# 标记: FRTH  预测: RMGA
# 标记: UKYH  预测: RMGA
# 标记: 8LU5  预测: RMGA
# 标记: 7501  预测: RMGA
# 标记: Q496  预测: RMGA
# 标记: D83L  预测: RMGA
# 标记: ANIX  预测: RMGA
# 标记: X2G0  预测: RMGA
# 标记: FWBE  预测: RMGA
# 标记: B329  预测: RMGA
# 标记: YTLU  预测: RMGA
# 标记: X47P  预测: RMGA
# 标记: IMQ3  预测: RMGA
# 标记: 3RSH  预测: RMGA
# 标记: JGR2  预测: RMGA
# 标记: ZCJV  预测: RMGA
# 标记: DO22  预测: RMGA
# 标记: DR8F  预测: RMGA
# 标记: R3L2  预测: RMGA
# 标记: MD0B  预测: RMGA
# 标记: WXHY  预测: RMGA
# 标记: OIX5  预测: RMGA
# 标记: 4TER  预测: RMGA
# 标记: HYP1  预测: RMGA
# 标记: ZC9C  预测: RMGA
# 标记: DMHA  预测: RMGA
# 标记: USMQ  预测: RMGA
# 标记: A19B  预测: RMGA
# 标记: 4I76  预测: RMGA
# 标记: ROLH  预测: RMGA
# 标记: 1YKN  预测: RMGA
# 标记: 7RDQ  预测: RMGA
# 标记: O19T  预测: RMGA
# 标记: SDXP  预测: RMGA
# 标记: UOSG  预测: RMGA
# 标记: O1WO  预测: RMGA
# 标记: JF2M  预测: RMGA
# 标记: FL8X  预测: RMGA
# 标记: 55J1  预测: RMGA
# 标记: NZD7  预测: RMGA
# 标记: L57G  预测: RMGA
# 标记: C5X7  预测: RMGA
# 标记: XX06  预测: RMGA
# 标记: Q95U  预测: RMGA
# 标记: IZTK  预测: RMGA
# 标记: UIPS  预测: RMGA
# 标记: EURR  预测: RMGA
# 标记: QENA  预测: RMGA
# 标记: 9LU7  预测: RMGA
# 标记: 4SRR  预测: RMGA
# 标记: M8N5  预测: RMGA
# 标记: 5E7N  预测: RMGA
# 标记: JQAK  预测: RMGA
# 标记: WVJT  预测: RMGA
# 标记: TQ2A  预测: RMGA
# 标记: N8KO  预测: RMGA
# 标记: UAK7  预测: RMGA
# 标记: 09WA  预测: RMGA
# 标记: OGGZ  预测: RMGA
# 标记: 3265  预测: RMGA
# 标记: P5NG  预测: RMGA
# 标记: 4ZWP  预测: RMGA
# 标记: IIH0  预测: RMGA
# 标记: QK6K  预测: RMGA
# 标记: H09G  预测: RMGA
# 标记: DZKI  预测: RMGA
# 标记: UUNK  预测: RMGA
# 标记: HDHY  预测: RMGA
# 标记: 33GQ  预测: RMGA
# 标记: LVY1  预测: RMGA
# 标记: ML2L  预测: RMGA
# 标记: 1USW  预测: RMGA
# 标记: JQVX  预测: RMGA
# 标记: CKOA  预测: RMGA
# 标记: XJU4  预测: RMGA
# 标记: IXLX  预测: RMGA
# 标记: 2G4U  预测: RMGA
# 标记: PZSH  预测: RMGA
# 标记: H6KV  预测: RMGA
# 标记: 2WGE  预测: RMGA
# 标记: C1ZN  预测: RMGA
# 标记: BE5N  预测: RMGA
# 标记: GEC1  预测: RMGA
# 标记: C5DD  预测: RMGA
# 标记: M91Y  预测: RMGA
# 标记: GOXU  预测: RMGA
# 标记: 31UG  预测: RMGA
# 标记: PZ1H  预测: RMGA
# 标记: 7GE6  预测: RMGA
# 标记: SZOY  预测: RMGA
# 标记: EPWD  预测: RMGA
# 标记: R2CH  预测: RMGA
# 标记: DL02  预测: RMGA
# 标记: TBPS  预测: RMGA
# 标记: 15XM  预测: RMGA
# 标记: 85GP  预测: RMGA
# 标记: GRRS  预测: RMGA
# 标记: NB8W  预测: RMGA
# 标记: 805Z  预测: RMGA
# 标记: PBI6  预测: RMGA
# 标记: JEG5  预测: RMGA
# 标记: EAFN  预测: RMGA
# 标记: PPW7  预测: RMGA
# 标记: 1VFB  预测: RMGA
# 标记: K0PS  预测: RMGA
# 标记: IAJV  预测: RMGA
# 标记: DE8M  预测: RMGA
# 标记: N3Q7  预测: RMGA
# 标记: LHID  预测: RMGA
# 标记: YKTW  预测: RMGA
# 标记: 34W3  预测: RMGA
# 标记: PRPE  预测: RMGA
# 标记: DSN0  预测: RMGA
# 标记: MM2F  预测: RMGA
# 标记: QKDG  预测: RMGA
# 标记: S09B  预测: RMGA
# 标记: IW73  预测: RMGA
# 标记: 5BKM  预测: RMGA
# 标记: 2UEI  预测: RMGA
# 标记: X8Z6  预测: RMGA
# 标记: KXOM  预测: RMGA
# 标记: FVU1  预测: RMGA
# 标记: Q3OR  预测: RMGA
# 标记: JXSU  预测: RMGA
# 标记: RPQ6  预测: RMGA
# 标记: A7HR  预测: RMGA
# 标记: YR3N  预测: RMGA
# 标记: HGNF  预测: RMGA
# 标记: RIRP  预测: RMGA
# 标记: P16L  预测: RMGA
# 标记: 3XS9  预测: RMGA
# 标记: R398  预测: RMGA
# 标记: 69PJ  预测: RMGA
# 标记: KGWW  预测: RMGA
# 标记: ZINF  预测: RMGA
# 标记: EMLJ  预测: RMGA
# 标记: CX17  预测: RMGA
# 标记: X44B  预测: RMGA
# 标记: WVLJ  预测: RMGA
# 标记: ZJ03  预测: RMGA
# 标记: AF21  预测: RMGA
# 标记: R961  预测: RMGA
# 标记: AGVU  预测: RMGA
# 标记: D82H  预测: RMGA
# 标记: 1M2U  预测: RMGA
# 标记: EA8N  预测: RMGA
# 标记: 2IM1  预测: RMGA
# 标记: FAOX  预测: RMGA
# 标记: 3XIO  预测: RMGA
# 标记: SB2V  预测: RMGA
# 标记: BVPI  预测: RMGA
# 标记: 5KZU  预测: RMGA
# 标记: I8B9  预测: RMGA
# 标记: YAS8  预测: RMGA
# 标记: 8DB6  预测: RMGA
# 标记: HKXS  预测: RMGA
# 标记: J1FG  预测: RMGA
# 标记: XW9O  预测: RMGA
# 标记: 3D7J  预测: RMGA
# 标记: LKKE  预测: RMGA
# 标记: UWV6  预测: RMGA
# 标记: S81M  预测: RMGA
# 标记: WL44  预测: RMGA
# 标记: YGNX  预测: RMGA
# 标记: CMBE  预测: RMGA
# 标记: Y9EP  预测: RMGA
# 标记: HOW6  预测: RMGA
# 标记: RBLL  预测: RMGA
# 标记: ZKVC  预测: RMGA
# 标记: LX0D  预测: RMGA
# 标记: LX90  预测: RMGA
# 标记: DIDZ  预测: RMGA
# 标记: VA50  预测: RMGA
# 标记: EF1T  预测: RMGA
# 标记: 4R9J  预测: RMGA
# 标记: JXG0  预测: RMGA
# 标记: TKJQ  预测: RMGA
# 标记: Q5BJ  预测: RMGA
# 标记: G6ZO  预测: RMGA
# 标记: MYIL  预测: RMGA
# 标记: 6GIG  预测: RMGA
# 标记: NICQ  预测: RMGA
# 标记: HH3U  预测: RMGA
# task: 1000  cost time: 17.09507179260254 s
# right/total----- 0 / 1000
# end...
